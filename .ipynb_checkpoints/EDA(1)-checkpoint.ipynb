# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["font.family"] = "NanumGothic"
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import RobustScaler

# %%
ctrain=pd.read_csv("./data/ctrain.csv")
ctrain.head()
# Out:
#      접수년월  질병경중등급코드  KCD등급코드  질병구분코드  발생지역구분코드  치료행위코드  의료기관구분코드  요양병원여부  \
# 0  201901         1        3       1         1      12         2       0
# 1  201901         3        8      22         4       2         1       1
# 2  201901         3        8      22         1       2         1       1
# 3  201901         3        8      23         2       8         2       0
# 4  201901         3        8      23         9       8         2       0
#
#    고객나이구분코드  부담보5년경과여부  ...  병원별평균수술청구보험금  병원별평균진단청구보험금  질병별평균입원청구보험금  \
# 0         3          0  ...        0.0000        0.0000        1.2612
# 1         4          0  ...        0.5770        0.0000        0.0023
# 2         4          0  ...        0.2885        0.0000        0.0023
# 3         9          0  ...        0.0680        0.0587        0.1920
# 4         0          0  ...        0.0000        0.0000        0.1920
#
#    질병별평균통원청구보험금  질병별평균수술청구보험금  질병별평균진단청구보험금   입원청구건수  수술청구건수  통원청구건수  target
# 0        1.2002        1.1701        0.9793  10.0000     0.0     2.0       1
# 1        0.0000        0.1508        0.0000   0.0000     1.0     0.0       0
# 2        0.0000        0.1508        0.0000   0.0000     1.0     0.0       1
# 3        0.0000        0.0863        0.0000   1.4444     0.0     0.0       1
# 4        0.0000        0.0863        0.0000   1.3333     0.0     0.0       1
#
# [5 rows x 33 columns]

# %%
category_list=['질병경중등급코드', 'KCD등급코드', '질병구분코드', '발생지역구분코드', '치료행위코드',
'의료기관구분코드', '요양병원여부', '고객나이구분코드', '부담보5년경과여부', '부실모집설계사계약여부',
'중도부가계약여부', '건강인우대계약가입여부', '보험사기이력고객여부', '보험료구간코드', '가입금액구간코드',
'청구일계약일간기간구분코드', '청구일부활일간기간구분코드']

# %%
for i in category_list:
    ctrain[i] = ctrain[i].astype("category")

# %%
print(ctrain["target"].value_counts())
sns.barplot(data=ctrain["target"].value_counts().reset_index(), x="index", y="target")
# Out:
# 1    226036
# 0     93793
# 2     58099
# Name: target, dtype: int64

# %%
for col in ctrain.columns[1:-1]:
    plt.figure(figsize = (10, 5))
    plt.title(f"{col}")
    sns.distplot(ctrain[col].values, kde=False)

# %%
corr=ctrain.corr()

# %%
corr["보험료구간코드"]
# Out:
# 접수년월            -0.028934
# 질병경중등급코드        -0.162604
# KCD등급코드         -0.052104
# 질병구분코드          -0.165399
# 발생지역구분코드         0.480089
# 치료행위코드           0.018919
# 의료기관구분코드         0.041802
# 요양병원여부          -0.067880
# 고객나이구분코드         0.446392
# 부담보5년경과여부        0.000086
# 부실모집설계사계약여부     -0.032570
# 중도부가계약여부        -0.026990
# 건강인우대계약가입여부     -0.013379
# 보험사기이력고객여부       0.019057
# 보험료구간코드          1.000000
# 가입금액구간코드         0.996139
# 통원횟수             0.027937
# 청구보험금           -0.059054
# 입원일수             0.086878
# 청구일계약일간기간구분코드   -0.932626
# 청구일부활일간기간구분코드    0.016048
# 병원별평균입원청구보험금     0.105613
# 병원별평균통원청구보험금     0.038606
# 병원별평균수술청구보험금     0.070061
# 병원별평균진단청구보험금     0.072636
# 질병별평균입원청구보험금     0.166925
# 질병별평균통원청구보험금     0.083852
# 질병별평균수술청구보험금     0.155968
# 질병별평균진단청구보험금     0.131765
# 입원청구건수           0.077636
# 수술청구건수          -0.018795
# 통원청구건수           0.025067
# target           0.355287
# Name: 보험료구간코드, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(ctrain.values, i) for i in range(ctrain.shape[1])]
vif["features"] = ctrain.columns
vif
# Out:
#     VIF Factor       features
# 0   199.474802           접수년월
# 1    14.740352       질병경중등급코드
# 2     1.767322        KCD등급코드
# 3    14.516059         질병구분코드
# 4     1.369377       발생지역구분코드
# 5     1.529914         치료행위코드
# 6     2.289035       의료기관구분코드
# 7     1.705980         요양병원여부
# 8     1.412741       고객나이구분코드
# 9     1.003322      부담보5년경과여부
# 10    1.003649    부실모집설계사계약여부
# 11    1.043796       중도부가계약여부
# 12    1.004386    건강인우대계약가입여부
# 13    1.062059     보험사기이력고객여부
# 14  138.455720        보험료구간코드
# 15  147.515576       가입금액구간코드
# 16    1.500976           통원횟수
# 17    1.339982          청구보험금
# 18    1.499279           입원일수
# 19    9.041404  청구일계약일간기간구분코드
# 20    1.024581  청구일부활일간기간구분코드
# 21    1.655161   병원별평균입원청구보험금
# 22    1.429370   병원별평균통원청구보험금
# 23    1.998354   병원별평균수술청구보험금
# 24    2.214408   병원별평균진단청구보험금
# 25    5.810881   질병별평균입원청구보험금
# 26    3.103741   질병별평균통원청구보험금
# 27    8.246625   질병별평균수술청구보험금
# 28    6.589351   질병별평균진단청구보험금
# 29    1.361926         입원청구건수
# 30    1.399008         수술청구건수
# 31    1.555120         통원청구건수
# 32    1.586381         target

# %%
for col in ctrain.columns:
    if col not in category_list:
        plt.figure(figsize = (10, 5))
        plt.title(f"{col}")
        sns.boxplot(ctrain[col].values)

# %%
ctrain["요양병원여부"].dtypes == "category"
# Out:
# True

# %%
RS = RobustScaler()

# %%
for col in ctrain.columns:
    if col not in category_list:
        ctrain[col]=RS.fit_transform(ctrain[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-4f596ba0b205> in <module>
#       1 for col in ctrain.columns:
#       2     if col not in category_list:
# ----> 3         ctrain[col]=RS.fit_transform(ctrain[col])
#
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#    1155         # the quantiles
#    1156         X = check_array(X, accept_sparse='csc', copy=self.copy, estimator=self,
# -> 1157                         dtype=FLOAT_DTYPES, force_all_finite='allow-nan')
#    1158
#    1159         q_min, q_max = self.quantile_range
#
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[201901. 201901. 201901. ... 201907. 201909. 201906.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
