# %%
#변수중요도 100 이하 : optt_nbtm_s, urlb_fc_yn, heltp_pf_ntyn, ac_rst_diff,
#smrtg_5y_passed_yn, nur_hosp_yn, mdct_inu_rclss_dcd, ar_rclss_cd, prm_nvcd,
#optt_blcnt_s

#다중공선성 가능성을 보이는 변수 : prm_nvcd/inamt_nvcd,

# %%
drop_col = ["optt_nbtm_s", "urlb_fc_yn", "heltp_pf_ntyn", "ac_rst_diff",
"smrtg_5y_passed_yn", "nur_hosp_yn", "mdct_inu_rclss_dcd", "ar_rclss_cd", 
"prm_nvcd", "optt_blcnt_s"]

# %%
import pandas as pd

# %%
train_df=pd.read_csv("./data/train.csv")
test_df=pd.read_csv("./data/test.csv")

# %%
train_df = train_df.drop(drop_col, axis=1)
train_df
# Out:
#             ID  ac_ctr_diff  hsp_avg_optt_bilg_isamt_s  \
# 0            0            6                     0.1303
# 1            1            6                     0.0000
# 2            2            6                     0.0000
# 3            3            4                     0.0197
# 4            4            5                     0.0000
# ...        ...          ...                        ...
# 377923  377923            6                     0.7997
# 377924  377924            0                     2.3047
# 377925  377925            0                     0.0000
# 377926  377926            6                     1.3784
# 377927  377927            6                     0.0000
#
#         hsp_avg_surop_bilg_isamt_s  fds_cust_yn  hspz_dys_s  inamt_nvcd  \
# 0                           0.0000            0      0.3452           4
# 1                           0.5770            0      0.0000           4
# 2                           0.2885            1      0.0000           6
# ...

# %%
test_df = test_df.drop(drop_col, axis=1)
test_df
# Out:
#           ID  ac_ctr_diff  hsp_avg_optt_bilg_isamt_s  \
# 0          0            5                     0.0000
# 1          1            6                     1.5266
# 2          2            6                     1.6061
# 3          3            6                     0.1228
# 4          4            6                     0.0000
# ...      ...          ...                        ...
# 22067  22067            6                     0.0000
# 22068  22068            6                     0.0000
# 22069  22069            4                     0.0000
# 22070  22070            5                     1.7263
# 22071  22071            6                     0.0000
#
#        hsp_avg_surop_bilg_isamt_s  fds_cust_yn  hspz_dys_s  inamt_nvcd  \
# 0                          0.2938            0      0.0000           9
# 1                          2.1745            0      0.0000           6
# 2                          1.6884            0      0.0000           3
# ...

# %%
train_df.to_csv("./data/train1.csv", index=False)
test_df.to_csv("./data/test1.csv", index=False)

# %%
import pandas as pd

# %%
pd.read_csv("./data/sample.csv")
# Out:
#           ID  target
# 0          0       0
# 1          1       0
# 2          2       0
# 3          3       0
# 4          4       0
# ...      ...     ...
# 22067  22067       0
# 22068  22068       0
# 22069  22069       0
# 22070  22070       0
# 22071  22071       0
#
# [22072 rows x 2 columns]
